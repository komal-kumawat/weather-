# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Summary of Weather.csv")
df
# Out:
# C:\Users\Anil kumar\AppData\Local\Temp\ipykernel_2736\4058078468.py:1: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Summary of Weather.csv")
#           STA        Date Precip  WindGustSpd    MaxTemp    MinTemp  \
# 0       10001    1942-7-1  1.016          NaN  25.555556  22.222222
# 1       10001    1942-7-2      0          NaN  28.888889  21.666667
# 2       10001    1942-7-3   2.54          NaN  26.111111  22.222222
# 3       10001    1942-7-4   2.54          NaN  26.666667  22.222222
# 4       10001    1942-7-5      0          NaN  26.666667  21.666667
# ...       ...         ...    ...          ...        ...        ...
# 119035  82506  1945-12-27      0          NaN  28.333333  18.333333
# 119036  82506  1945-12-28  9.906          NaN  29.444444  18.333333
# 119037  82506  1945-12-29      0          NaN  28.333333  18.333333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 31 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STA          119040 non-null  int64
#  1   Date         119040 non-null  object
#  2   Precip       119040 non-null  object
#  3   WindGustSpd  532 non-null     float64
#  4   MaxTemp      119040 non-null  float64
#  5   MinTemp      119040 non-null  float64
#  6   MeanTemp     119040 non-null  float64
#  7   Snowfall     117877 non-null  object
#  8   PoorWeather  34237 non-null   object
#  9   YR           119040 non-null  int64
#  10  MO           119040 non-null  int64
#  11  DA           119040 non-null  int64
#  12  PRCP         117108 non-null  object
#  13  DR           533 non-null     float64
#  14  SPD          532 non-null     float64
#  15  MAX          118566 non-null  float64
#  16  MIN          118572 non-null  float64
#  17  MEA          118542 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  STA  WindGustSpd        MaxTemp        MinTemp  \
# count  119040.000000   532.000000  119040.000000  119040.000000
# mean    29659.435795    37.774534      27.045111      17.789511
# std     20953.209402    10.297808       8.717817       8.334572
# min     10001.000000    18.520000     -33.333333     -38.333333
# 25%     11801.000000    29.632000      25.555556      15.000000
# 50%     22508.000000    37.040000      29.444444      21.111111
# 75%     33501.000000    43.059000      31.666667      23.333333
# max     82506.000000    75.932000      50.000000      34.444444
#
#             MeanTemp             YR             MO             DA          DR  \
# count  119040.000000  119040.000000  119040.000000  119040.000000  533.000000
# mean       22.411631      43.805284       6.726016      15.797530   26.998124
# std         8.297982       1.136718       3.425561       8.794541   15.221732
# ...

# %%
# sns.pairplot(df)

# %% [markdown]
# # EDA

# %% [markdown]
# ### missing data

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['STA', 'Date', 'Precip', 'WindGustSpd', 'MaxTemp', 'MinTemp',
#        'MeanTemp', 'Snowfall', 'PoorWeather', 'YR', 'MO', 'DA', 'PRCP', 'DR',
#        'SPD', 'MAX', 'MIN', 'MEA', 'SNF', 'SND', 'FT', 'FB', 'FTI', 'ITH',
#        'PGT', 'TSHDSBRSGF', 'SD3', 'RHX', 'RHN', 'RVG', 'WTE'],
#       dtype='object')

# %%
# CLEANING DATA
df.drop(df.iloc[:,7:],axis = 1,inplace = True)
df.drop('WindGustSpd',axis = 1,inplace = True)

# %%
df
# Out:
#           STA        Date Precip    MaxTemp    MinTemp   MeanTemp
# 0       10001    1942-7-1  1.016  25.555556  22.222222  23.888889
# 1       10001    1942-7-2      0  28.888889  21.666667  25.555556
# 2       10001    1942-7-3   2.54  26.111111  22.222222  24.444444
# 3       10001    1942-7-4   2.54  26.666667  22.222222  24.444444
# 4       10001    1942-7-5      0  26.666667  21.666667  24.444444
# ...       ...         ...    ...        ...        ...        ...
# 119035  82506  1945-12-27      0  28.333333  18.333333  23.333333
# 119036  82506  1945-12-28  9.906  29.444444  18.333333  23.888889
# 119037  82506  1945-12-29      0  28.333333  18.333333  23.333333
# 119038  82506  1945-12-30      0  28.333333  18.333333  23.333333
# 119039  82506  1945-12-31      0  29.444444  17.222222  23.333333
#
# [119040 rows x 6 columns]

# %%
sns.set_style('whitegrid')

# %%
sns.distplot(df['MaxTemp'],kde = False,bins = 30,color = 'darkred')
# Out:
# C:\Users\Anil kumar\AppData\Local\Temp\ipykernel_2736\143319385.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxTemp'],kde = False,bins = 30,color = 'darkred')
# <Axes: xlabel='MaxTemp'>

# %%
sns.distplot(df['MinTemp'],kde = False,bins = 30,color = 'darkred')
# Out:
# C:\Users\Anil kumar\AppData\Local\Temp\ipykernel_2736\3598332983.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MinTemp'],kde = False,bins = 30,color = 'darkred')
# <Axes: xlabel='MinTemp'>

# %%
sns.distplot(df['MeanTemp'],kde = False,bins = 30,color = 'darkred')
# Out:
# C:\Users\Anil kumar\AppData\Local\Temp\ipykernel_2736\3627944343.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MeanTemp'],kde = False,bins = 30,color = 'darkred')
# <Axes: xlabel='MeanTemp'>

# %%
sns.jointplot(x= df['MaxTemp'],y = df['MinTemp'],color = 'darkred')

# %%
sns.jointplot(x= df['MeanTemp'],y = df['MinTemp'],color = 'darkred')

# %%
sns.jointplot(x= df['MaxTemp'],y = df['MeanTemp'],color = 'darkred')

# %%
X = df[['MinTemp']]
y = df[['MaxTemp']]
# X = pd.get_dummies(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
MEE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
rscore = r2_score(y_test,y_pred)
print("MEE:",MEE)
print("MSE:",MSE)
print("r_score:",rscore)
# Out:
# MEE: 3.1845598259707395
# MSE: 17.47195662523142
# r_score: 0.7722853308415473

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred, color = 'red')
plt.xlabel('Y Test')
plt.ylabel('Y Predicted')
# Out:
# Text(0, 0.5, 'Y Predicted')
